# %% [markdown]
# # Attorney Finder

# %% [markdown]
# ### Imports

# %%
import ipywidgets as widgets
from scipy import stats
from fuzzywuzzy import process
from operator import itemgetter
from stanfordcorenlp import StanfordCoreNLP as sfnlp
import re

import pandas as pd
import numpy as np
import datetime
import json
from bs4 import BeautifulSoup
import requests
from googleapiclient.discovery import build


import itertools
from scipy.sparse import csr_matrix, coo_matrix

import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt

from elasticsearch import Elasticsearch
import warnings
warnings.filterwarnings('ignore')

full = pd.read_csv('full.csv')
full.drop('Unnamed: 0', axis=1, inplace=True)
full['email'] = [i.lower() for i in full['email']]
full = full.groupby(['email', 'case_id']).agg({'weight':'sum'}).reset_index()
case_cite_tag = pd.DataFrame.from_csv('case_cite_tag.csv')
case_cite_tag.drop('weight', axis=1, inplace=True)
full = full.merge(case_cite_tag, how='left', on='case_id')
cites_common = pd.DataFrame.from_csv('cites_common.csv')
full = full.merge(cites_common, how='left', on='case_id')
full = full[full['cite_common_count'] < 250]
full['pt_score'] = full['updated_NOS']/full['cite_common_count']

# %%
widgets.ToggleButton(
    value=False,
    description='Click me',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Description',
    icon='check'
)

# %%
def str_clean(string):
    try:
        return string.replace('\n',' ').strip()
    except AttributeError:
        return np.nan

# %%
def plaintiff_from_brief_id(plaint, brief_id):
    if plaint is np.nan:
        try:
            return brief_id.split('_')[0].split('-v-')[0].replace('-', ' ')
        except IndexError:
            return plaint
    else:
        return plaint
    
    
def defendant_from_brief_id(defend, brief_id):
    if defend is np.nan:
        try:
            return brief_id.split('_')[0].split('-v-')[1].replace('-', ' ')
        except IndexError:
            return defend
    else:
        return defend

# %%
def drop_empty(string):
    if " " == string:
        return
    if "" == string:
        return
    else:
        return string

# %%
def remove_fluff(string, reg, insert=''):
    return reg.sub(insert, string)

# %%
def cleaning(blah):
    try:
        wah = blah.replace(';', ',')
    except AttributeError:
        return blah
    reg = re.compile('and DOES [0-9]', re.IGNORECASE)

    inc1 = re.compile(' INC\.', re.IGNORECASE)
    inc2 = re.compile(' INC ', re.IGNORECASE)
    inc3 = re.compile(' INC$', re.IGNORECASE)
    llc = re.compile('L(\.)?L(\.)?C(\.)?', re.IGNORECASE)
    ltd = re.compile('L(\.)?T(\.)?D(\.)?', re.IGNORECASE)
    gmbh = re.compile('GMBH', re.IGNORECASE)
    co = re.compile('CO(\.)? ', re.IGNORECASE)
    etal = re.compile('et al(\.)?', re.IGNORECASE)
    inre1 = re.compile('in re\.', re.IGNORECASE)
    inre2 = re.compile('in re ', re.IGNORECASE)
    lp = re.compile('(l)?(\.)?l(\.)?p(\.)?', re.IGNORECASE)
    pc = re.compile(' P(\.)?C(\.)?', re.IGNORECASE)

    filt_list = [inc1, inc2, inc3, llc, ltd, gmbh, co, etal, inre1, inre2, lp, pc]

    for i in filt_list:
        wah = remove_fluff(wah, i)
    try:
        result = reg.search(wah)
        wah = wah[:result.start()].split(',')
    except AttributeError:
        wah = wah.split(',')
    wah = [i for i in wah if drop_empty(i) != None]
    wah = [i.strip() for i in wah]
    for i in range(len(wah)):
        if (wah[i][:3] == 'and') or (wah[i][:3] == 'AND'):
            wah[i] = wah[i][4:]
    return wah

# %%
party_mast = pd.DataFrame.from_csv('parties.csv')

# %%
def state_city_us(bid, desc):
    if desc == 'individual':
        return 'Individual'
    reg_1 = re.compile('^USA$', re.IGNORECASE)
    reg_2 = re.compile('^state of', re.IGNORECASE)
    reg_3 = re.compile('state of$', re.IGNORECASE)
    reg_4 = re.compile('^United States of America$', re.IGNORECASE)
    reg_5 = re.compile('^the city', re.IGNORECASE)
    reg_6 = re.compile('city of$', re.IGNORECASE)
    reg_6 = re.compile('^city of', re.IGNORECASE)
    
    filt_list = [reg_1, reg_2, reg_3, reg_4, reg_5, reg_6]
    try:
        tf_list = [bool(i.search(bid)) for i in filt_list]
    except TypeError:
        return np.nan
    if sum(tf_list) >= 1:
        return 'City/State/US'
    else:
        return np.nan
        
party_mast['desc'] = [state_city_us(party_mast['parties'][i], party_mast['desc'][i]) for i in range(len(party_mast))]

# %%
party_mast.head(40)
# Out:
#                                              brief_id  \
# 0   gabriel-et-al-v-fischer-et-al_memorandum-of-la...
# 1   williamson-v-verizon-services-corp-et-al_reply...
# 2   price-v-chalmette-refining-llc-et-al_motion-fo...
# 3   veasey-et-al-v-wilkins-jr_reply-to-response-to...
# 4   clearlake-shipping-pte-ltd-v-ow-bunker-switzer...
# 5   baltazar-et-al-v-apple-inc_motion-to-strike-22...
# 6   sierra-club-v-mccarthy_motion-for-summary-judg...
# 7   log-cabin-republicans-v-united-states-of-ameri...
# 8   hysitron-incorporated-v-mts-systems-corporatio...
# 9   citizens-for-responsibility-and-ethics-in-wash...
# 10  doe-v-corrections-corporation-of-america-et-al...
# 11  morgan-et-al-v-the-antioch-company-litigation-...
# 12  peyovich-v-world-mortgage-company-et-al_motion...
# 13           desai-v-adt-security-services-inc_motion
# 14  mccormick-et-al-v-dresdale-et-al_motion-to-uns...
# 15  chamber-of-commerce-of-the-united-states-of-am...
# 16  laydon-v-mizuho-bank-ltd-et-al_reply-memorandu...
# 17  safari-club-international-et-al-v-jewell-et-al...
# 18  robinson-v-carpenter_reply-to-response-to-habe...
# 19  leachman-cattle-of-colorado-llc-et-al-v-americ...
# 20  in-re-franklin-bank-corp-securities-litigation...
# 21  aetna-life-insurance-company-v-methodist-hospi...
# 22  united-states-of-america-v-9311000-in-us-curre...
# 23  transcontinental-gas-pipe-line-company-llc-v-2...
# 24  micro-focus-us-inc-v-express-scripts-inc_motio...
# 25  abella-v-student-aid-center-inc-et-al_response...
# 26  peden-v-bww-law-group-llc-et-al_motion-to-dism...
# 27  krystal-inc-et-al-v-china-united-transport-inc...
# 28  weinstein-v-cardis-enterprises-international-n...
# 29  terech-v-first-resolution-management-corporati...
# 30  scott-v-nuvell-financial-services-llc-et-al_re...
# 31  collins-aikman-corporation-et-al-v-stockman-et...
# 32  harden-manufacturing-corporation-v-pfizer-inc-...
# 33  owl-shipping-llc-v-dalian-suntime-internationa...
# 34  theodore-and-marjorie-charron-andres-mares-mur...
# 35  engel-v-third-avenue-management-llc-et-al_memo...
# 36  the-estate-of-cathleen-mary-cahill-v-united-st...
# 37  ferrell-v-ditech-financial-llc_motion-for-part...
# 38  banks-v-united-states-marshals-service-et-al_m...
# 39  pfizer-inc-et-al-v-mylan-inc-et-al_response-to...
#
#                                               parties           desc
# 0                                             gabriel     Individual
# 1                                          williamson     Individual
# 2                                               price     Individual
# 3                                              veasey     Individual
# 4                              clearlake shipping pte            NaN
# 5                                            baltazar     Individual
# 6                                         sierra club            NaN
# 7                               log cabin republicans            NaN
# 8                               hysitron incorporated            NaN
# 9   citizens for responsibility and ethics in wash...            NaN
# 10                                                doe     Individual
# 11                                             morgan     Individual
# 12                                           peyovich            NaN
# 13                                              desai     Individual
# 14                                          mccormick     Individual
# 15  chamber of commerce of the united states of am...            NaN
# 16                                             laydon     Individual
# 17                          safari club international            NaN
# 18                                           robinson     Individual
# 19                        leachman cattle of colorado            NaN
# 20           franklin bank corp securities litigation            NaN
# 21                       aetna life insurance company            NaN
# 22                           united states of america  City/State/US
# 23             transcontinental gas pipe line company            NaN
# 24                                     micro focus us            NaN
# 25                                             abella     Individual
# 26                                              peden     Individual
# 27                                            krystal            NaN
# 28                                          weinstein     Individual
# 29                                             terech            NaN
# 30                                              scott     Individual
# 31                         collins aikman corporation            NaN
# 32                   harden manufacturing corporation            NaN
# 33                                       owl shipping            NaN
# 34  theodore and marjorie charron andres mares mur...            NaN
# 35                                              engel     Individual
# 36                 the estate of cathleen mary cahill            NaN
# 37                                            ferrell     Individual
# 38                                              banks     Individual
# 39                                             pfizer            NaN

# %% [markdown]
# # Creating Attorney Matrix

# %%
attorney_map = {}
case_map = {}
attorney_idx = 0
case_idx = 0

for index,email,case_id, weight,updated_NOS, cites_common_count, pt_score in full.itertuples():
    if email not in attorney_map:
        attorney_map[email] = attorney_idx
        attorney_idx+=1
    if case_id not in case_map:
        case_map[case_id] = case_idx
        case_idx+=1
I,J, data = [],[],[]
for index, attorney, case_id, weight,updated_NOS, cites_common_count, pt_score in full.itertuples():
    I.append(attorney_map[attorney])
    J.append(case_map[case_id])
    data.append(weight) 
n = len(attorney_map)
m = len(case_map)
M = coo_matrix((data, (I, J)), (n, m))
M = M.tocsr()
M = (M.dot(M.transpose())) 
for i in range(M.shape[0]):
    M[i,i] = 0
del I,J,data
emails = list(np.unique(full['email']))

# %%
def top_results(attorneys, matrix1=M, num_results=5, end1=emails, begin1=attorney_map, printing1 = True):
    A = matrix1.shape[0]
    I, J, V = [], [], []
    for i in attorneys:
        I.append(attorney_map[i])
        J.append(0)
        V.append(1)
    q_vec = coo_matrix((V,(I,J)),shape=(A, 1))
    resultant_vec = matrix1.dot(q_vec).todense()
    results = [item for sublist in resultant_vec.tolist() for item in sublist]
    results_indexed = list(enumerate(results))
    sorted_results = sorted(results_indexed, key=itemgetter(1))
    final_index = sorted_results[-num_results:]
#     attorneys_res = []
#     for i in final_index:
#         attorneys_res.append(end1[i[0]])
#     if printing1:
#         count = num_results
#         for i in attorneys_res:
#             print('Attorney number %d: ' %count, str(i))
#             count -=1
#     return attorneys_res + attorneys
    return final_index, resultant_vec

# %%
def two_pass(attorneys, matrix=M, first_pass =20, second_pass = 5, end=emails, begin=attorney_map, printing = False, print_out = True):
    index, vector = top_results(attorneys, matrix1=matrix, num_results=first_pass, end1=end, begin1=begin, printing1=printing)
    vector = np.matrix(np.array([0 for i in range(M.shape[0])]).reshape(M.shape[0], 1))
    for i in index:
        vector = vector + top_results([emails[i[0]]])[1]
    for i in attorneys:
        vector[attorney_map[i]] = 0
    results = [item for sublist in vector.tolist() for item in sublist]
    results_indexed = list(enumerate(results))
    sorted_results = sorted(results_indexed, key=itemgetter(1))
    final_index = sorted_results[-second_pass:]
    attorneys_res = []
    for i in final_index:
        attorneys_res.append(end[i[0]])
    if print_out:
        count = second_pass
        for i in attorneys_res:
            print('Attorney number %d: ' %count, str(i))
            count -=1
    return attorneys_res

# %%
two_pass([a2])
# Out:
# Attorney number 5:  pstphillip@lowey.com
# Attorney number 4:  vbriganti@lowey.com
# Attorney number 3:  lnussbaum@nussbaumpc.com
# Attorney number 2:  ghorn@lowey.com
# Attorney number 1:  clovell@lshllp.com
# ['pstphillip@lowey.com',
#  'vbriganti@lowey.com',
#  'lnussbaum@nussbaumpc.com',
#  'ghorn@lowey.com',
#  'clovell@lshllp.com']

# %%
a1 = 'gjobson@fenwick.com'
a2 = 'aargiropoulos@ebglaw.com'
a3 = 'lnussbaum@nussbaumpc.com'

# %%
blah = full[(full['email'] == a1)]['case_id']
wah = full[(full['email'] == 'dorian.daley@oracle.com')]['case_id']
set(blah).intersection(set(wah))
# Out:
# {'firoozye-v-earthlink-network', 'summit-mach-tool-mfg-v-victor-cnc-systems'}

# %%
first_pass = widgets.IntSlider(min=0,max=20,step=1,value=5, description='First Pass Value:')
display(first_pass)

# %%
URL="https://3a7721e6.qb0x.com:30022"

## Initializing Elastic search object

es = Elasticsearch(URL)#, use_ssl= True, verify_certs=False)

lawyers = es.search(index="briefs", body={
    "query": {
        "match": { "plaintiff_emails": 'dorian.daley@oracle.com'}
    },
    "_source": ["plaintiff_emails"],
    "size":100000
})['hits']['hits']
lawyers
# Out:
# [{'_id': 'oracle-america-inc-et-al-v-hewlett-packard-enterprise-company_motion-to-strike-87-amended-answer-to-complaint-hpes-affirmative-defense-nos',
#   '_index': 'briefs',
#   '_score': 3.7747705,
#   '_source': {'plaintiff_emails': ['brittany.lovejoy@lw.com',
#     'chris.yates@lw.com',
#     'christopher.campbell@lw.com',
#     'deborah.miller@oracle.com',
#     'dorian.daley@oracle.com',
#     'jeff.ross@oracle.com',
#     'meaghan.thomas-kennedy@lw.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-america-inc-et-al-v-hewlett-packard-enterprise-company_response-to',
#   '_index': 'briefs',
#   '_score': 3.3380613,
#   '_source': {'plaintiff_emails': ['brittany.lovejoy@lw.com',
#     'chris.yates@lw.com',
#     'christopher.campbell@lw.com',
#     'deborah.miller@oracle.com',
#     'dorian.daley@oracle.com',
#     'jeff.ross@oracle.com',
#     'meaghan.thomas-kennedy@lw.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-usa-inc-et-al-v-rimini-street-inc-et-al_motion-to-dismiss',
#   '_index': 'briefs',
#   '_score': 2.8272455,
#   '_source': {'plaintiff_emails': ['dorian.daley@oracle.com',
#     'aloeb@bsfllp.com',
#     'deborah.miller@oracle.com',
#     'fnorton@bsfllp.com',
#     'bree.hann@bingham.com',
#     'geoff.howard@bingham.com',
#     'jim.maroulis@oracle.com',
#     'jneukom@BSFLLP.com',
#     'john.polito@bingham.com',
#     'kringgenberg@BSFLLP.com',
#     'kristen.palumbo@bingham.com',
#     'sholtzman@bsfllp.com',
#     'thomas.hixson@bingham.com',
#     'rpocker@bsfllp.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-america-inc-v-oregon-health-insurance-exchange-corporation-et-al_motion-for-judgment-on-the-pleadings',
#   '_index': 'briefs',
#   '_score': 2.7771,
#   '_source': {'plaintiff_emails': ['blegaard@schwabe.com',
#     'deborah.miller@oracle.com',
#     'dorian.daley@oracle.com',
#     'econnell@orrick.com',
#     'jeden@schwabe.com',
#     'kjohnson-mckewan@orrick.com',
#     'peggy.bruggman@oracle.com',
#     'rshwarts@orrick.com',
#     'petranovichm@lanepowell.com',
#     'frenchp@lanepowell.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-america-inc-v-oregon-health-insurance-exchange-corporation-et-al_response-in-opposition-plaintiff-oracle-america-incs-corrected-opposition-to',
#   '_index': 'briefs',
#   '_score': 2.6639862,
#   '_source': {'plaintiff_emails': ['blegaard@schwabe.com',
#     'deborah.miller@oracle.com',
#     'dorian.daley@oracle.com',
#     'econnell@orrick.com',
#     'jeden@schwabe.com',
#     'kjohnson-mckewan@orrick.com',
#     'peggy.bruggman@oracle.com',
#     'rshwarts@orrick.com',
#     'petranovichm@lanepowell.com',
#     'frenchp@lanepowell.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-america-inc-v-oregon-health-insurance-exchange-corporation-et-al_motion-to-dismiss-for-failure-to-state-a-claim-and-failure-to-join-necessary-and',
#   '_index': 'briefs',
#   '_score': 2.6639862,
#   '_source': {'plaintiff_emails': ['blegaard@schwabe.com',
#     'deborah.miller@oracle.com',
#     'dorian.daley@oracle.com',
#     'econnell@orrick.com',
#     'jeden@schwabe.com',
#     'kjohnson-mckewan@orrick.com',
#     'peggy.bruggman@oracle.com',
#     'rshwarts@orrick.com',
#     'petranovichm@lanepowell.com',
#     'frenchp@lanepowell.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_reply-memorandum-in-support-re-motion-to-compel-modification-to-protective',
#   '_index': 'briefs',
#   '_score': 2.3396668,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_response-in-support-re-motion-to-seal-plaintiffs-administrative-motion-to',
#   '_index': 'briefs',
#   '_score': 2.3240964,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_reply-3',
#   '_index': 'briefs',
#   '_score': 2.120764,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_motion-to-compel-production-of-financial-information-from-plaintiffs',
#   '_index': 'briefs',
#   '_score': 2.120764,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_memorandum-in-opposition-defendants-opposition-to-plaintiffs-258-motion-for',
#   '_index': 'briefs',
#   '_score': 2.0868201,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_reply-memorandum-re-motion-to-compel-production-of-documents-related-to-damages',
#   '_index': 'briefs',
#   '_score': 2.0868201,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_opposition-to-136-motion-to-compel-production-of-clawed-back-documents-redacted',
#   '_index': 'briefs',
#   '_score': 2.0868201,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_reply-memorandum-re-motion-for-entry-of-judgment-under-rule',
#   '_index': 'briefs',
#   '_score': 2.0847669,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_motion-to-modify-the-protective-order-and-to-compel-deposition-testimony-and',
#   '_index': 'briefs',
#   '_score': 2.0847669,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_reply-2',
#   '_index': 'briefs',
#   '_score': 2.0847669,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_response-to-re-defendants-objections-to-evidence',
#   '_index': 'briefs',
#   '_score': 2.0819445,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_motion-for-sanctions-redacted-pursuant-to-frcp',
#   '_index': 'briefs',
#   '_score': 2.0819445,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_motion-to-compel-redacted-motion-to-compel-discovery-concerning-third-party',
#   '_index': 'briefs',
#   '_score': 2.0819445,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_opposition-to-309-plaintiffs-administrative-motion-for-clarification-of-may',
#   '_index': 'briefs',
#   '_score': 2.0689247,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_memorandum-in-opposition-defendants-opposition-to-plaintiffs-motion-to-amend-',
#   '_index': 'briefs',
#   '_score': 2.0689247,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_response-in-support-re-motion-to-seal-document-defendants-administrative-motion-1',
#   '_index': 'briefs',
#   '_score': 2.0689247,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_reply-in-support-of-defendants-frcp',
#   '_index': 'briefs',
#   '_score': 2.0689247,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_motion-for-partial-summary-judgment-1',
#   '_index': 'briefs',
#   '_score': 2.0632482,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_motion-for-judgment-as-a-matter-of-law-and-motion-for-new-trial',
#   '_index': 'briefs',
#   '_score': 2.0632482,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_motion-to-compel-production-of-damages-related-documents-and-information',
#   '_index': 'briefs',
#   '_score': 2.0632482,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_motion-to-stay-defendants-motion-for-stay-of-execution-of-judgment-through',
#   '_index': 'briefs',
#   '_score': 2.048981,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_motion-for-leave-to-file-amended-complaint',
#   '_index': 'briefs',
#   '_score': 2.048981,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_memorandum-in-opposition-oracles-opposition-to-defendants-frcp-1',
#   '_index': 'briefs',
#   '_score': 2.048981,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_motion-for-partial-summary-judgment-defendants-notice-of-motion-and-motion-for',
#   '_index': 'briefs',
#   '_score': 2.0334904,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_memorandum-in-opposition-oracles-opposition-to-defendants-frcp',
#   '_index': 'briefs',
#   '_score': 2.0334904,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_response-defendants-response-to-plaintiffs-administrative-motion-to-file',
#   '_index': 'briefs',
#   '_score': 2.0334904,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_response-2',
#   '_index': 'briefs',
#   '_score': 2.0334904,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_response-in-support-of-595-plaintiffs-administrative-motion-to-permit',
#   '_index': 'briefs',
#   '_score': 2.0334904,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_memorandum-in-opposition-re-motion-for-partial-summary-judgment-defendants',
#   '_index': 'briefs',
#   '_score': 1.9617229,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_reply-to-96-opposition-to-defendants-objections-to-special-masters-report-and',
#   '_index': 'briefs',
#   '_score': 1.9617229,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_motion-to-seal-plaintiffs-administrative-motion-to-file-under-seal-documents',
#   '_index': 'briefs',
#   '_score': 1.9617229,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_response-in-support-re-motion-to-seal-document-defendants-administrative-motion-2',
#   '_index': 'briefs',
#   '_score': 1.9617229,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_opposition-to-294-defendants-motion-to-compel-further-copyright-information',
#   '_index': 'briefs',
#   '_score': 1.960808,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_motion-of-joshua-l-fuchs-for-leave-to-appear-in-pro-hac-vice',
#   '_index': 'briefs',
#   '_score': 1.960808,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_response-re-proposed-order-266-motion-to-seal-exhibit-a-to-february-9-joint',
#   '_index': 'briefs',
#   '_score': 1.960808,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_motion-to-compel-discovery-relevant-to-plaintiffs-copyright-claims',
#   '_index': 'briefs',
#   '_score': 1.960808,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_reply-memorandum-re-motion-for-leave-to-file-amended-complaint',
#   '_index': 'briefs',
#   '_score': 1.960808,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_response-in-support-re-motion-to-seal-document-defendants-administrative-motion',
#   '_index': 'briefs',
#   '_score': 1.960808,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_memorandum-in-opposition-to-570-oracles-motion-to-modify-the-protective-order',
#   '_index': 'briefs',
#   '_score': 1.9300472,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_reply-in-support-of-566-motion-to-compel',
#   '_index': 'briefs',
#   '_score': 1.9300472,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_reply-memorandum-in-support-of-motion-to-compel-production-of-financial',
#   '_index': 'briefs',
#   '_score': 1.9300472,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_response-in-support-re-motion-to-seal-defendants-information-supporting',
#   '_index': 'briefs',
#   '_score': 1.9300472,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_response-to-575-plaintiffs-administrative-motion-to-permit-plaintiffs-to-file',
#   '_index': 'briefs',
#   '_score': 1.9300472,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_opposition-to-88-defendants-objections-to-special-masters-report-and',
#   '_index': 'briefs',
#   '_score': 1.9300472,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_response-in-support-of-motion-to-compel-discovery-concerning-third-party-support',
#   '_index': 'briefs',
#   '_score': 1.9071057,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_reply-memorandum-in-support-of-motion-for-sanctions-pursuant-to-fed-r-civ-p',
#   '_index': 'briefs',
#   '_score': 1.9071057,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_response-re-plaintiffs-administrative-motion-to-file-their-motion-to-compel-and',
#   '_index': 'briefs',
#   '_score': 1.9071057,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_memorandum-in-opposition-oracles-opposition-to-defendants-motion-to-compel',
#   '_index': 'briefs',
#   '_score': 1.9071057,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_motion-for-entry-of-judgment-under-rule',
#   '_index': 'briefs',
#   '_score': 1.9071057,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_response-defendants-response-to-plaintiffs-objections-to-order-for-sanctions',
#   '_index': 'briefs',
#   '_score': 1.9071057,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_response-to-1014-proposed-judgment',
#   '_index': 'briefs',
#   '_score': 1.9071057,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_reply-in-support-of-294-their-motion-to-compel-discovery-relevant-to-plaintiffs',
#   '_index': 'briefs',
#   '_score': 1.8435767,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_memorandum-in-opposition-defendants-opposition-to-plaintiffs-motion-to-compel-1',
#   '_index': 'briefs',
#   '_score': 1.8435767,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_reply-to-re-opposition-to-defendants-motion-for-partial-summary-judgment-1',
#   '_index': 'briefs',
#   '_score': 1.8435767,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_memorandum-in-opposition-to-566-defendants-motion-to-compel',
#   '_index': 'briefs',
#   '_score': 1.8435767,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_memorandum-in-opposition-defendants-opposition-to-plaintiffs-motion-to-compel',
#   '_index': 'briefs',
#   '_score': 1.8435767,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_motion-to-compel-discovery-related-to-hyperion-retek-and-ebs-products',
#   '_index': 'briefs',
#   '_score': 1.8435767,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_reply-to-re-opposition-to-defendants-motion-for-partial-summary-judgment',
#   '_index': 'briefs',
#   '_score': 1.8435767,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_memorandum-in-opposition-re-motion-to-compel-production-of-damages-related',
#   '_index': 'briefs',
#   '_score': 1.8435767,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_response-1',
#   '_index': 'briefs',
#   '_score': 1.8412498,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_motion-to-intervene',
#   '_index': 'briefs',
#   '_score': 1.8412498,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_motion-for-extension-of-time-to-complete-discovery',
#   '_index': 'briefs',
#   '_score': 1.8412498,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_motion-to-compel-production-of-documents-related-to-damages-model-and',
#   '_index': 'briefs',
#   '_score': 1.8412498,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_motion-to-stay-or-extend-time-to-comply-with-july-3-2008-discovery-order',
#   '_index': 'briefs',
#   '_score': 1.8412498,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_motion-for-leave-to-file-alternative-stipulated-complaint',
#   '_index': 'briefs',
#   '_score': 1.8412498,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_response-in-support-defendants-response-to-plaintiffs-administrative-motion-to',
#   '_index': 'briefs',
#   '_score': 1.8412498,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_reply-to-re-defendants-opposition-to-plaintiffs-motion-to-compel-production-of',
#   '_index': 'briefs',
#   '_score': 1.8412498,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-corporation-et-al-v-sap-ag-et-al_motion-for-partial-summary-judgment-redacted',
#   '_index': 'briefs',
#   '_score': 1.8412498,
#   '_source': {'plaintiff_emails': ['donn.pickett@bingham.com',
#     'bree.hann@bingham.com',
#     'chad.russell@bingham.com',
#     'chris.hockett@dpw.com',
#     'dboies@bsfllp.com',
#     'dorian.daley@oracle.com',
#     'geoff.howard@bingham.com',
#     'hollyhouse@paulhastings.com',
#     'jennifer.gloss@oracle.com',
#     'sholtzman@bsfllp.com',
#     'tanya.dumas@bingham.com',
#     'fnorton@bsfllp.com',
#     'zalinder@sideman.com',
#     'cdj@bcltlaw.com',
#     'john.polito@bingham.com']},
#   '_type': 'doc'},
#  {'_id': 'oracle-america-inc-v-myriad-group-ag_response-re-motion-to-dismiss-andor-quash-service-of-process-or-in-the',
#   '_index': 'briefs',
#   '_score': 0.6676857,
#   '_source': {'plaintiff_emails': ['amanda.fitzsimmons@dlapiper.com',
#     'andrew.temkin@oracle.com',
#     'brooke.kim@dlapiper.com',
#     'cbeal@dillongerardi.com',
#     'ebrannen@book.com',
#     'jeffrey.shohet@dlapiper.com',
#     'ragrawal@mofo.com']},
#   '_type': 'doc'}]

# %% [markdown]
# ### USPTO Querying

# %%
what = !node ../tess-search-master/cli.js 'Mizuho'[bi,mp,ti] and 'bank'[gs]

# %%
what[12]

# %%
what = what[what.index('Logging out of TESS...')+1:]

# %%
what

# %%
import io
from IPython.display import display
import fileupload

def _upload():

    _upload_widget = fileupload.FileUploadWidget()

    def _cb(change):
        decoded = io.StringIO(change['owner'].data.decode('utf-8'))
        filename = change['owner'].filename
        print('Uploaded `{}` ({:.2f} kB)'.format(
            filename, len(decoded.read()) / 2 **10))

    _upload_widget.observe(_cb, names='data')
    display(_upload_widget)

_upload()

# %%
uploader = fileupload.FileUploadWidget()

def _handle_upload(change):
    w = change['owner']
    with open(w.filename, 'wb') as f:
        f.write(w.data)
    print('Uploaded `{}` ({:.2f} kB)'.format(
        w.filename, len(w.data) / 2**10))

uploader.observe(_handle_upload, names='data')

display(uploader)
# Out:
# <bound method Widget.on_displayed of <fileupload.widget.FileUploadWidget object at 0x000001F9B20044E0>>

# %%
import ipywidgets as widgets

# %%
first_pass = widgets.IntSlider(min=0,max=20,step=1,value=5, description='First Pass Value:')
display(first_pass)

# %%
second_pass = widgets.IntSlider(min=0,max=20,step=1,value=5, description='Second Pass Value:')
display(second_pass)
